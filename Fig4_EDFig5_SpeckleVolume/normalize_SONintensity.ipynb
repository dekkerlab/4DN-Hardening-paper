# %%
# %%
import numpy as np
from readlif.reader import LifFile
from skimage import io
import os


# %%
def normalize_stack_preserve_decay(stack, method='percentile', percentile=99.5):
    """
    Normalize a z-stack to consistent intensity ranges while preserving
    the natural decay pattern across z-slices.

    Parameters:
    -----------
    stack : ndarray
        3D array (z, y, x)
    method : str
        'percentile' - normalize to percentile across all slices
        'mean' - normalize to mean intensity
        'median' - normalize to median intensity
    percentile : float
        Percentile value to use if method='percentile'

    Returns:
    --------
    normalized_stack : ndarray
        Normalized stack preserving relative intensity decay
    global_norm : float
        The normalization factor used
    """

    # Calculate global normalization factor across entire stack
    if method == 'percentile':
        global_norm = np.percentile(stack, percentile)
    elif method == 'mean':
        global_norm = np.mean(stack[stack > 0])  # Exclude background
    elif method == 'median':
        global_norm = np.median(stack[stack > 0])
    else:
        raise ValueError(f"Unknown method: {method}")

    # Normalize entire stack by global factor
    normalized = stack.astype(np.float32) / global_norm

    return normalized, global_norm


# %%
def save_normalized_stack(normalized_stack, output_path, bit_depth=16, voxel_size=None):
    """
    Save normalized stack as TIFF with appropriate bit depth and metadata.

    Parameters:
    -----------
    normalized_stack : ndarray
        Normalized stack (values typically 0-1)
    output_path : str
        Path to save TIFF
    bit_depth : int
        8 or 16 bit output
    voxel_size : dict or None
        Dictionary with 'x', 'y', 'z' keys for voxel dimensions in micrometers
    """

    if bit_depth == 16:
        max_val = 65535
        dtype = np.uint16
    elif bit_depth == 8:
        max_val = 255
        dtype = np.uint8
    else:
        raise ValueError("bit_depth must be 8 or 16")

    # Scale to bit depth range
    output = np.clip(normalized_stack * max_val, 0, max_val).astype(dtype)

    # Prepare metadata for TIFF
    metadata = {}
    if voxel_size is not None:
        # ImageJ-compatible metadata
        # Resolution is pixels per unit (inverse of voxel size)
        # TIFF uses pixels per cm by default, convert to pixels per µm
        resolution_x = 1.0 / voxel_size['x'] if voxel_size['x'] > 0 else 1.0
        resolution_y = 1.0 / voxel_size['y'] if voxel_size['y'] > 0 else 1.0

        # For ImageJ compatibility, store spacing
        metadata = {
            'spacing': voxel_size['z'],  # Z-spacing in µm
            'unit': 'um',  # micrometers
            'axes': 'ZYX'
        }

        # Save with resolution information
        io.imsave(
            output_path,
            output,
            check_contrast=False,
            resolution=(resolution_x, resolution_y),
            metadata=metadata
        )
    else:
        io.imsave(output_path, output, check_contrast=False)

    print(f"Saved: {os.path.basename(output_path)}")


# %%
def normalize_channel2_from_lif(lif_path, image_index=0,
                                method='percentile', percentile=99.5,
                                save_output=True, output_path=None):
    """
    Load a .lif file and normalize only channel 2 for a specific image.
    """

    lif = LifFile(lif_path)
    img = lif.get_image(image_index)

    # Get dimensions
    n_channels = img.channels
    n_z = img.dims.z
    n_y = img.dims.y
    n_x = img.dims.x

    # Verify channel 2 exists (0-indexed, so channel 2 is the 3rd channel)
    if n_channels < 3:
        raise ValueError(f"Image only has {n_channels} channels. Channel 2 (index 2) does not exist.")

    # Load stack for channel 2 (index 2)
    stack = []
    for z in range(n_z):
        frame = img.get_frame(z=z, t=0, c=1)
        stack.append(frame)

    stack = np.array(stack)

    # Normalize
    normalized, norm_factor = normalize_stack_preserve_decay(
        stack, method=method, percentile=percentile
    )

    metadata = {
        'image_name': img.name,
        'image_index': image_index,
        'n_channels': n_channels,
        'n_z': n_z,
        'n_y': n_y,
        'n_x': n_x,
        'norm_factor': norm_factor,
        'method': method,
        'channel': 2,
        'percentile': percentile if method == 'percentile' else None,
        'original_min': stack.min(),
        'original_max': stack.max(),
        'normalized_min': normalized.min(),
        'normalized_max': normalized.max()
    }

    # Save if requested
    if save_output:
        if output_path is None:
            # Auto-generate output path with image name in ch2normalized folder
            base_dir = os.path.dirname(lif_path)
            lif_basename = os.path.splitext(os.path.basename(lif_path))[0]
            output_dir = os.path.join(base_dir, f"{lif_basename}_ch2normalized")
            os.makedirs(output_dir, exist_ok=True)

            # Sanitize image name for filename
            safe_name = "".join(c for c in img.name if c.isalnum() or c in (' ', '-', '_')).strip()
            safe_name = safe_name.replace(' ', '_')
            output_path = os.path.join(output_dir, f"img{image_index:03d}_{safe_name}.tif")

        save_normalized_stack(normalized, output_path, bit_depth=16)

    return normalized, metadata


# %%
# ---- Batch normalization ----
def normalize_all_images_channel2(lif_path, method='percentile', percentile=99.5,
                                   save_output=True):
    """
    Normalize channel 2 for all images in a .lif file.
    Saves to a folder named: <lif_filename>_ch2normalized

    Parameters:
    -----------
    lif_path : str
        Path to .lif file
    method : str
        Normalization method
    percentile : float
        Percentile for normalization
    save_output : bool
        Whether to save normalized stacks

    Returns:
    --------
    results : list of dict
        List of metadata dictionaries for each processed image
    output_dir : str
        Path to the output directory where files were saved
    """

    lif = LifFile(lif_path)
    n_images = lif.num_images

    # Create output directory
    base_dir = os.path.dirname(lif_path)
    if not base_dir:
        base_dir = "."
    lif_basename = os.path.splitext(os.path.basename(lif_path))[0]
    output_dir = os.path.join(base_dir, f"{lif_basename}_ch2normalized_test")

    if save_output:
        os.makedirs(output_dir, exist_ok=True)

    print(f"Found {n_images} images -> {output_dir}")

    # Process each image
    results = []
    for i in range(n_images):
        try:
            # Generate output path
            img = lif.get_image(i)
            safe_name = "".join(c for c in img.name if c.isalnum() or c in (' ', '-', '_')).strip()
            safe_name = safe_name.replace(' ', '_')
            output_path = os.path.join(output_dir, f"img{i:03d}_{safe_name}.tif")

            normalized, metadata = normalize_channel2_from_lif(
                lif_path,
                image_index=i,
                method=method,
                percentile=percentile,
                save_output=save_output,
                output_path=output_path
            )

            results.append(metadata)

        except Exception as e:
            print(f"ERROR processing image {i}: {e}")
            continue

    print(f"Done: {len(results)}/{n_images} normalized")

    return results, output_dir


# %%
# ---- Set path ----
lif_path = "C:/pathToLif/file.lif"


# %%
# ---- Process ALL images ----
# saves to <lif_filename>_ch2normalized/ folder
results, output_dir = normalize_all_images_channel2(
    lif_path,
    method='percentile',
    percentile=100,
    save_output=True
)
# Out:
# Found 301 images -> /abyss/dlafonta/imaging/IF_volumes_4DN/04242026-ALL-speckles_noLNG_ch2normalized_test
# Saved: img000_HB-SRRM2-488-K27ac-594HB-SRRM2-488-K27ac-594_1.tif
# Saved: img001_Lightning_027HB-SRRM2-488-K27ac-594_2.tif
# Saved: img002_Lightning_001HB-SRRM2-488-K27ac-594_3.tif
# Saved: img003_Lightning_002HB-SRRM2-488-K27ac-594_4.tif
# Saved: img004_Lightning_003HB-SRRM2-488-K27ac-594_5.tif
# Saved: img005_Lightning_004HB-SRRM2-488-K27ac-594_6.tif
# Saved: img006_Lightning_005HB-SRRM2-488-K27ac-594_7.tif
# Saved: img007_Lightning_006HB-SRRM2-488-K27ac-594_8.tif
# Saved: img008_Lightning_007HB-SRRM2-488-K27ac-594_9.tif
# Saved: img009_Lightning_008HB-SRRM2-488-K27ac-594_10.tif
# Saved: img010_Lightning_009HB-SRRM2-488-K27ac-594_11.tif
# Saved: img011_Lightning_010HB-SRRM2-488-K27ac-594_12.tif
# Saved: img012_Lightning_011HB-SRRM2-488-K27ac-594_13.tif
# Saved: img013_Lightning_012HB-SRRM2-488-K27ac-594_14.tif
# Saved: img014_Lightning_013HB-SRRM2-488-K27ac-594_15.tif
# Saved: img015_Lightning_014HB-SRRM2-488-K27ac-594_16.tif
# Saved: img016_Lightning_015HB-SRRM2-488-K27ac-594_17.tif
# Saved: img017_Lightning_016HB-SRRM2-488-K27ac-594_18.tif
# Saved: img018_Lightning_017HB-SRRM2-488-K27ac-594_19.tif
# Saved: img019_Lightning_018HB-SRRM2-488-K27ac-594_20.tif
# Saved: img020_Lightning_019HB-SRRM2-488-K27ac-594_21.tif
# Saved: img021_Lightning_020HB-SRRM2-488-K27ac-594_22.tif
# Saved: img022_Lightning_021HB-SRRM2-488-K27ac-594_23.tif
# Saved: img023_Lightning_022HB-SRRM2-488-K27ac-594_24.tif
# Saved: img024_Lightning_023HB-SRRM2-488-K27ac-594_25.tif
# Saved: img025_Lightning_024HB-SRRM2-488-K27ac-594_26.tif
# Saved: img026_Lightning_025HB-SRRM2-488-K27ac-594_27.tif
# Saved: img027_Lightning_026HB-SRRM2-488-K27ac-594_28.tif
# Saved: img028_Lightning_028HB-SRRM2-488-K27ac-594_29.tif
# Saved: img029_DE7-SRRM2-488-K27ac-594DE7-SRRM2-488-K27ac-594_1.tif
# Saved: img030_Lightning_029DE7-SRRM2-488-K27ac-594_2.tif
# Saved: img031_Lightning_030DE7-SRRM2-488-K27ac-594_3.tif
# Saved: img032_Lightning_031DE7-SRRM2-488-K27ac-594_4.tif
# Saved: img033_Lightning_032DE7-SRRM2-488-K27ac-594_5.tif
# Saved: img034_Lightning_033DE7-SRRM2-488-K27ac-594_6.tif
# Saved: img035_Lightning_034DE7-SRRM2-488-K27ac-594_7.tif
# Saved: img036_Lightning_035DE7-SRRM2-488-K27ac-594_8.tif
# Saved: img037_Lightning_036DE7-SRRM2-488-K27ac-594_9.tif
# Saved: img038_Lightning_037DE7-SRRM2-488-K27ac-594_10.tif
# Saved: img039_Lightning_038DE7-SRRM2-488-K27ac-594_11.tif
# Saved: img040_Lightning_039DE7-SRRM2-488-K27ac-594_12.tif
# Saved: img041_Lightning_040DE7-SRRM2-488-K27ac-594_13.tif
# Saved: img042_Lightning_041DE7-SRRM2-488-K27ac-594_14.tif
# Saved: img043_Lightning_042DE7-SRRM2-488-K27ac-594_15.tif
# Saved: img044_Lightning_043DE7-SRRM2-488-K27ac-594_16.tif
# Saved: img045_Lightning_044DE7-SRRM2-488-K27ac-594_17.tif
# Saved: img046_Lightning_045DE7-SRRM2-488-K27ac-594_18.tif
# Saved: img047_Lightning_046DE7-SRRM2-488-K27ac-594_19.tif
# Saved: img048_Lightning_047DE7-SRRM2-488-K27ac-594_20.tif
# Saved: img049_Lightning_048DE7-SRRM2-488-K27ac-594_21.tif
# Saved: img050_Lightning_049DE7-SRRM2-488-K27ac-594_22.tif
# Saved: img051_Lightning_050DE7-SRRM2-488-K27ac-594_23.tif
# Saved: img052_Lightning_051DE7-SRRM2-488-K27ac-594_24.tif
# Saved: img053_Lightning_053DE7-SRRM2-488-K27ac-594_25.tif
# Saved: img054_Lightning_052DE7-SRRM2-488-K27ac-594_26.tif
# Saved: img055_Lightning_054DE7-SRRM2-488-K27ac-594_27.tif
# Saved: img056_DE6-SRRM2-488-K27ac-594DE6-SRRM2-488-K27ac-594_1.tif
# Saved: img057_Lightning_055DE6-SRRM2-488-K27ac-594_2.tif
# Saved: img058_Lightning_056DE6-SRRM2-488-K27ac-594_3.tif
# Saved: img059_Lightning_057DE6-SRRM2-488-K27ac-594_4.tif
# Saved: img060_Lightning_058DE6-SRRM2-488-K27ac-594_5.tif
# Saved: img061_Lightning_059DE6-SRRM2-488-K27ac-594_6.tif
# Saved: img062_Lightning_060DE6-SRRM2-488-K27ac-594_7.tif
# Saved: img063_Lightning_061DE6-SRRM2-488-K27ac-594_8.tif
# Saved: img064_Lightning_062DE6-SRRM2-488-K27ac-594_9.tif
# Saved: img065_Lightning_063DE6-SRRM2-488-K27ac-594_10.tif
# Saved: img066_Lightning_064DE6-SRRM2-488-K27ac-594_11.tif
# Saved: img067_Lightning_065DE6-SRRM2-488-K27ac-594_12.tif
# Saved: img068_Lightning_066DE6-SRRM2-488-K27ac-594_13.tif
# Saved: img069_Lightning_067DE6-SRRM2-488-K27ac-594_14.tif
# Saved: img070_Lightning_068DE6-SRRM2-488-K27ac-594_15.tif
# Saved: img071_Lightning_069DE6-SRRM2-488-K27ac-594_16.tif
# Saved: img072_Lightning_070DE6-SRRM2-488-K27ac-594_17.tif
# Saved: img073_Lightning_071DE6-SRRM2-488-K27ac-594_18.tif
# Saved: img074_Lightning_072DE6-SRRM2-488-K27ac-594_19.tif
# Saved: img075_Lightning_073DE6-SRRM2-488-K27ac-594_20.tif
# Saved: img076_Lightning_074DE6-SRRM2-488-K27ac-594_21.tif
# Saved: img077_Lightning_075DE6-SRRM2-488-K27ac-594_22.tif
# Saved: img078_Lightning_076DE6-SRRM2-488-K27ac-594_23.tif
# Saved: img079_Lightning_077DE6-SRRM2-488-K27ac-594_24.tif
# Saved: img080_Lightning_078DE6-SRRM2-488-K27ac-594_25.tif
# Saved: img081_Lightning_079DE6-SRRM2-488-K27ac-594_26.tif
# Saved: img082_Lightning_080DE6-SRRM2-488-K27ac-594_27.tif
# Saved: img083_Lightning_081DE6-SRRM2-488-K27ac-594_28.tif
# Saved: img084_DE5-SRRM2-488-K27ac-594DE5-SRRM2-488-K27ac-594_1.tif
# Saved: img085_Lightning_082DE5-SRRM2-488-K27ac-594_2.tif
# Saved: img086_Lightning_083DE5-SRRM2-488-K27ac-594_3.tif
# Saved: img087_Lightning_084DE5-SRRM2-488-K27ac-594_4.tif
# Saved: img088_Lightning_085DE5-SRRM2-488-K27ac-594_5.tif
# Saved: img089_Lightning_086DE5-SRRM2-488-K27ac-594_6.tif
# Saved: img090_Lightning_087DE5-SRRM2-488-K27ac-594_7.tif
# Saved: img091_Lightning_088DE5-SRRM2-488-K27ac-594_8.tif
# Saved: img092_Lightning_089DE5-SRRM2-488-K27ac-594_9.tif
# Saved: img093_Lightning_090DE5-SRRM2-488-K27ac-594_10.tif
# Saved: img094_Lightning_091DE5-SRRM2-488-K27ac-594_11.tif
# Saved: img095_Lightning_092DE5-SRRM2-488-K27ac-594_12.tif
# Saved: img096_Lightning_093DE5-SRRM2-488-K27ac-594_13.tif
# Saved: img097_Lightning_094DE5-SRRM2-488-K27ac-594_14.tif
# Saved: img098_Lightning_095DE5-SRRM2-488-K27ac-594_15.tif
# Saved: img099_Lightning_096DE5-SRRM2-488-K27ac-594_16.tif
# Saved: img100_Lightning_097DE5-SRRM2-488-K27ac-594_17.tif
# Saved: img101_Lightning_098DE5-SRRM2-488-K27ac-594_18.tif
# Saved: img102_Lightning_099DE5-SRRM2-488-K27ac-594_19.tif
# Saved: img103_Lightning_100DE5-SRRM2-488-K27ac-594_20.tif
# Saved: img104_Lightning_101DE5-SRRM2-488-K27ac-594_21.tif
# Saved: img105_Lightning_102DE5-SRRM2-488-K27ac-594_22.tif
# Saved: img106_Lightning_103DE5-SRRM2-488-K27ac-594_23.tif
# Saved: img107_Lightning_104DE5-SRRM2-488-K27ac-594_24.tif
# Saved: img108_Lightning_105DE5-SRRM2-488-K27ac-594_25.tif
# Saved: img109_Lightning_106DE5-SRRM2-488-K27ac-594_26.tif
# Saved: img110_Lightning_107DE5-SRRM2-488-K27ac-594_27.tif
# Saved: img111_Lightning_108DE5-SRRM2-488-K27ac-594_28.tif
# Saved: img112_DE4-SRRM2-488-K27ac-594DE4-SRRM2-488-K27ac-594_1.tif
# Saved: img113_Lightning_109DE4-SRRM2-488-K27ac-594_2.tif
# Saved: img114_Lightning_110DE4-SRRM2-488-K27ac-594_3.tif
# Saved: img115_Lightning_111DE4-SRRM2-488-K27ac-594_4.tif
# Saved: img116_Lightning_112DE4-SRRM2-488-K27ac-594_5.tif
# Saved: img117_Lightning_113DE4-SRRM2-488-K27ac-594_6.tif
# Saved: img118_Lightning_115DE4-SRRM2-488-K27ac-594_8.tif
# Saved: img119_Lightning_116DE4-SRRM2-488-K27ac-594_9.tif
# Saved: img120_Lightning_117DE4-SRRM2-488-K27ac-594_10.tif
# Saved: img121_Lightning_118DE4-SRRM2-488-K27ac-594_11.tif
# Saved: img122_Lightning_119DE4-SRRM2-488-K27ac-594_12.tif
# Saved: img123_Lightning_120DE4-SRRM2-488-K27ac-594_13.tif
# Saved: img124_Lightning_121DE4-SRRM2-488-K27ac-594_14.tif
# Saved: img125_Lightning_122DE4-SRRM2-488-K27ac-594_15.tif
# Saved: img126_Lightning_123DE4-SRRM2-488-K27ac-594_16.tif
# Saved: img127_Lightning_124DE4-SRRM2-488-K27ac-594_17.tif
# Saved: img128_Lightning_125DE4-SRRM2-488-K27ac-594_18.tif
# Saved: img129_Lightning_126DE4-SRRM2-488-K27ac-594_19.tif
# Saved: img130_Lightning_127DE4-SRRM2-488-K27ac-594_20.tif
# Saved: img131_Lightning_128DE4-SRRM2-488-K27ac-594_21.tif
# Saved: img132_Lightning_129DE4-SRRM2-488-K27ac-594_22.tif
# Saved: img133_Lightning_130DE4-SRRM2-488-K27ac-594_23.tif
# Saved: img134_Lightning_131DE4-SRRM2-488-K27ac-594_24.tif
# Saved: img135_Lightning_132DE4-SRRM2-488-K27ac-594_25.tif
# Saved: img136_Lightning_133DE4-SRRM2-488-K27ac-594_26.tif
# Saved: img137_Lightning_134DE4-SRRM2-488-K27ac-594_27.tif
# Saved: img138_DE3-SRRM2-488-K27ac-594DE3-SRRM2-488-K27ac-594_1.tif
# Saved: img139_Lightning_135DE3-SRRM2-488-K27ac-594_2.tif
# Saved: img140_Lightning_136DE3-SRRM2-488-K27ac-594_3.tif
# Saved: img141_Lightning_137DE3-SRRM2-488-K27ac-594_4.tif
# Saved: img142_Lightning_138DE3-SRRM2-488-K27ac-594_5.tif
# Saved: img143_Lightning_139DE3-SRRM2-488-K27ac-594_6.tif
# Saved: img144_Lightning_140DE3-SRRM2-488-K27ac-594_7.tif
# Saved: img145_Lightning_141DE3-SRRM2-488-K27ac-594_8.tif
# Saved: img146_Lightning_142DE3-SRRM2-488-K27ac-594_9.tif
# Saved: img147_Lightning_143DE3-SRRM2-488-K27ac-594_10.tif
# Saved: img148_Lightning_144DE3-SRRM2-488-K27ac-594_11.tif
# Saved: img149_Lightning_145DE3-SRRM2-488-K27ac-594_12.tif
# Saved: img150_Lightning_146DE3-SRRM2-488-K27ac-594_13.tif
# Saved: img151_Lightning_147DE3-SRRM2-488-K27ac-594_14.tif
# Saved: img152_Lightning_148DE3-SRRM2-488-K27ac-594_15.tif
# Saved: img153_Lightning_149DE3-SRRM2-488-K27ac-594_16.tif
# Saved: img154_Lightning_150DE3-SRRM2-488-K27ac-594_17.tif
# Saved: img155_Lightning_151DE3-SRRM2-488-K27ac-594_18.tif
# Saved: img156_Lightning_152DE3-SRRM2-488-K27ac-594_19.tif
# Saved: img157_Lightning_153DE3-SRRM2-488-K27ac-594_20.tif
# Saved: img158_Lightning_154DE3-SRRM2-488-K27ac-594_21.tif
# Saved: img159_Lightning_155DE3-SRRM2-488-K27ac-594_22.tif
# Saved: img160_Lightning_156DE3-SRRM2-488-K27ac-594_23.tif
# Saved: img161_Lightning_157DE3-SRRM2-488-K27ac-594_24.tif
# Saved: img162_Lightning_158DE3-SRRM2-488-K27ac-594_25.tif
# Saved: img163_Lightning_159DE3-SRRM2-488-K27ac-594_26.tif
# Saved: img164_Lightning_160DE3-SRRM2-488-K27ac-594_27.tif
# Saved: img165_DE2-SRRM2-488-K27ac-594DE2-SRRM2-488-K27ac-594_1.tif
# Saved: img166_Lightning_161DE2-SRRM2-488-K27ac-594_2.tif
# Saved: img167_Lightning_162DE2-SRRM2-488-K27ac-594_3.tif
# Saved: img168_Lightning_163DE2-SRRM2-488-K27ac-594_4.tif
# Saved: img169_Lightning_164DE2-SRRM2-488-K27ac-594_5.tif
# Saved: img170_Lightning_165DE2-SRRM2-488-K27ac-594_6.tif
# Saved: img171_Lightning_166DE2-SRRM2-488-K27ac-594_7.tif
# Saved: img172_Lightning_167DE2-SRRM2-488-K27ac-594_8.tif
# Saved: img173_Lightning_168DE2-SRRM2-488-K27ac-594_9.tif
# Saved: img174_Lightning_169DE2-SRRM2-488-K27ac-594_10.tif
# Saved: img175_Lightning_170DE2-SRRM2-488-K27ac-594_11.tif
# Saved: img176_Lightning_171DE2-SRRM2-488-K27ac-594_12.tif
# Saved: img177_Lightning_172DE2-SRRM2-488-K27ac-594_13.tif
# Saved: img178_Lightning_173DE2-SRRM2-488-K27ac-594_14.tif
# Saved: img179_Lightning_174DE2-SRRM2-488-K27ac-594_15.tif
# Saved: img180_Lightning_175DE2-SRRM2-488-K27ac-594_16.tif
# Saved: img181_Lightning_176DE2-SRRM2-488-K27ac-594_17.tif
# Saved: img182_Lightning_177DE2-SRRM2-488-K27ac-594_18.tif
# Saved: img183_Lightning_178DE2-SRRM2-488-K27ac-594_19.tif
# Saved: img184_Lightning_179DE2-SRRM2-488-K27ac-594_20.tif
# Saved: img185_Lightning_180DE2-SRRM2-488-K27ac-594_21.tif
# Saved: img186_Lightning_181DE2-SRRM2-488-K27ac-594_22.tif
# Saved: img187_Lightning_182DE2-SRRM2-488-K27ac-594_23.tif
# Saved: img188_Lightning_183DE2-SRRM2-488-K27ac-594_24.tif
# Saved: img189_Lightning_184DE2-SRRM2-488-K27ac-594_25.tif
# Saved: img190_Lightning_185DE2-SRRM2-488-K27ac-594_26.tif
# Saved: img191_DE1-SRRM2-488-K27ac-594DE1-SRRM2-488-K27ac-594_1.tif
# Saved: img192_Lightning_186DE1-SRRM2-488-K27ac-594_2.tif
# Saved: img193_Lightning_187DE1-SRRM2-488-K27ac-594_3.tif
# Saved: img194_Lightning_188DE1-SRRM2-488-K27ac-594_4.tif
# Saved: img195_Lightning_189DE1-SRRM2-488-K27ac-594_5.tif
# Saved: img196_Lightning_190DE1-SRRM2-488-K27ac-594_6.tif
# Saved: img197_Lightning_191DE1-SRRM2-488-K27ac-594_7.tif
# Saved: img198_Lightning_192DE1-SRRM2-488-K27ac-594_8.tif
# Saved: img199_Lightning_193DE1-SRRM2-488-K27ac-594_9.tif
# Saved: img200_Lightning_194DE1-SRRM2-488-K27ac-594_10.tif
# Saved: img201_Lightning_195DE1-SRRM2-488-K27ac-594_11.tif
# Saved: img202_Lightning_196DE1-SRRM2-488-K27ac-594_12.tif
# Saved: img203_Lightning_197DE1-SRRM2-488-K27ac-594_13.tif
# Saved: img204_Lightning_198DE1-SRRM2-488-K27ac-594_14.tif
# Saved: img205_Lightning_199DE1-SRRM2-488-K27ac-594_15.tif
# Saved: img206_Lightning_200DE1-SRRM2-488-K27ac-594_16.tif
# Saved: img207_Lightning_201DE1-SRRM2-488-K27ac-594_17.tif
# Saved: img208_Lightning_202DE1-SRRM2-488-K27ac-594_18.tif
# Saved: img209_Lightning_203DE1-SRRM2-488-K27ac-594_19.tif
# Saved: img210_Lightning_204DE1-SRRM2-488-K27ac-594_20.tif
# Saved: img211_Lightning_205DE1-SRRM2-488-K27ac-594_21.tif
# Saved: img212_Lightning_206DE1-SRRM2-488-K27ac-594_22.tif
# Saved: img213_Lightning_207DE1-SRRM2-488-K27ac-594_23.tif
# Saved: img214_Lightning_208DE1-SRRM2-488-K27ac-594_24.tif
# Saved: img215_Lightning_209DE1-SRRM2-488-K27ac-594_25.tif
# Saved: img216_Lightning_210DE1-SRRM2-488-K27ac-594_26.tif
# Saved: img217_DE-SRRM2-488-K27ac-594DE-SRRM2-488-K27ac-594_1.tif
# Saved: img218_Lightning_212DE-SRRM2-488-K27ac-594_3.tif
# Saved: img219_Lightning_213DE-SRRM2-488-K27ac-594_4.tif
# Saved: img220_Lightning_214DE-SRRM2-488-K27ac-594_5.tif
# Saved: img221_Lightning_215DE-SRRM2-488-K27ac-594_6.tif
# Saved: img222_Lightning_216DE-SRRM2-488-K27ac-594_7.tif
# Saved: img223_Lightning_217DE-SRRM2-488-K27ac-594_8.tif
# Saved: img224_Lightning_218DE-SRRM2-488-K27ac-594_9.tif
# Saved: img225_Lightning_219DE-SRRM2-488-K27ac-594_10.tif
# Saved: img226_Lightning_220DE-SRRM2-488-K27ac-594_11.tif
# Saved: img227_Lightning_221DE-SRRM2-488-K27ac-594_12.tif
# Saved: img228_Lightning_222DE-SRRM2-488-K27ac-594_13.tif
# Saved: img229_Lightning_223DE-SRRM2-488-K27ac-594_14.tif
# Saved: img230_Lightning_224DE-SRRM2-488-K27ac-594_15.tif
# Saved: img231_Lightning_225DE-SRRM2-488-K27ac-594_16.tif
# Saved: img232_Lightning_226DE-SRRM2-488-K27ac-594_17.tif
# Saved: img233_Lightning_227DE-SRRM2-488-K27ac-594_18.tif
# Saved: img234_Lightning_228DE-SRRM2-488-K27ac-594_19.tif
# Saved: img235_Lightning_229DE-SRRM2-488-K27ac-594_20.tif
# Saved: img236_Lightning_230DE-SRRM2-488-K27ac-594_21.tif
# Saved: img237_Lightning_231DE-SRRM2-488-K27ac-594_22.tif
# Saved: img238_iHep-SRRM2-488-K27ac-594iHep-SRRM2-488-K27ac-594_1.tif
# Saved: img239_Lightning_001_000iHep-SRRM2-488-K27ac-594_2.tif
# Saved: img240_Lightning_002_000iHep-SRRM2-488-K27ac-594_3.tif
# Saved: img241_Lightning_003_000iHep-SRRM2-488-K27ac-594_4.tif
# Saved: img242_Lightning_004_000iHep-SRRM2-488-K27ac-594_5.tif
# Saved: img243_Lightning_005_000iHep-SRRM2-488-K27ac-594_6.tif
# Saved: img244_Lightning_006_000iHep-SRRM2-488-K27ac-594_7.tif
# Saved: img245_Lightning_007_000iHep-SRRM2-488-K27ac-594_8.tif
# Saved: img246_Lightning_008_000iHep-SRRM2-488-K27ac-594_9.tif
# Saved: img247_Lightning_009_000iHep-SRRM2-488-K27ac-594_10.tif
# Saved: img248_Lightning_010_000iHep-SRRM2-488-K27ac-594_11.tif
# Saved: img249_Lightning_011_000iHep-SRRM2-488-K27ac-594_12.tif
# Saved: img250_Lightning_012_000iHep-SRRM2-488-K27ac-594_13.tif
# Saved: img251_Lightning_013_000iHep-SRRM2-488-K27ac-594_14.tif
# Saved: img252_Lightning_014_000iHep-SRRM2-488-K27ac-594_15.tif
# Saved: img253_Lightning_015_000iHep-SRRM2-488-K27ac-594_16.tif
# Saved: img254_Lightning_016_000iHep-SRRM2-488-K27ac-594_17.tif
# Saved: img255_Lightning_017_000iHep-SRRM2-488-K27ac-594_18.tif
# Saved: img256_Lightning_018_000iHep-SRRM2-488-K27ac-594_19.tif
# Saved: img257_Lightning_019_000iHep-SRRM2-488-K27ac-594_20.tif
# Saved: img258_Lightning_020_000iHep-SRRM2-488-K27ac-594_21.tif
# Saved: img259_Lightning_021_000iHep-SRRM2-488-K27ac-594_22.tif
# Saved: img260_Lightning_022_000iHep-SRRM2-488-K27ac-594_23.tif
# Saved: img261_Lightning_023_000iHep-SRRM2-488-K27ac-594_24.tif
# Saved: img262_mHep-SRRM2-488-K27ac-594mHep-SRRM2-488-K27ac-594_1.tif
# Saved: img263_Lightning_024_000mHep-SRRM2-488-K27ac-594_2.tif
# Saved: img264_Lightning_025_000mHep-SRRM2-488-K27ac-594_3.tif
# Saved: img265_Lightning_026_000mHep-SRRM2-488-K27ac-594_4.tif
# Saved: img266_Lightning_027_000mHep-SRRM2-488-K27ac-594_5.tif
# Saved: img267_Lightning_028_000mHep-SRRM2-488-K27ac-594_6.tif
# Saved: img268_Lightning_029_000mHep-SRRM2-488-K27ac-594_7.tif
# Saved: img269_Lightning_030_000mHep-SRRM2-488-K27ac-594_8.tif
# Saved: img270_Lightning_031_000mHep-SRRM2-488-K27ac-594_9.tif
# Saved: img271_Lightning_032_000mHep-SRRM2-488-K27ac-594_10.tif
# Saved: img272_Lightning_033_000mHep-SRRM2-488-K27ac-594_11.tif
# Saved: img273_Lightning_034_000mHep-SRRM2-488-K27ac-594_12.tif
# Saved: img274_Lightning_035_000mHep-SRRM2-488-K27ac-594_13.tif
# Saved: img275_Lightning_036_000mHep-SRRM2-488-K27ac-594_14.tif
# Saved: img276_Lightning_037_000mHep-SRRM2-488-K27ac-594_15.tif
# Saved: img277_Lightning_038_000mHep-SRRM2-488-K27ac-594_16.tif
# Saved: img278_Lightning_039_000mHep-SRRM2-488-K27ac-594_17.tif
# Saved: img279_ES-SRRM2-488-K27ac-594ES-SRRM2-488-K27ac-594_1.tif
# Saved: img280_Lightning_040_000ES-SRRM2-488-K27ac-594_2.tif
# Saved: img281_Lightning_041_000ES-SRRM2-488-K27ac-594_3.tif
# Saved: img282_Lightning_042_000ES-SRRM2-488-K27ac-594_4.tif
# Saved: img283_Lightning_043_000ES-SRRM2-488-K27ac-594_5.tif
# Saved: img284_Lightning_044_000ES-SRRM2-488-K27ac-594_6.tif
# Saved: img285_Lightning_045_000ES-SRRM2-488-K27ac-594_7.tif
# Saved: img286_Lightning_046_000ES-SRRM2-488-K27ac-594_8.tif
# Saved: img287_Lightning_047_000ES-SRRM2-488-K27ac-594_9.tif
# Saved: img288_Lightning_048_000ES-SRRM2-488-K27ac-594_10.tif
# Saved: img289_Lightning_049_000ES-SRRM2-488-K27ac-594_11.tif
# Saved: img290_Lightning_050_000ES-SRRM2-488-K27ac-594_12.tif
# Saved: img291_Lightning_051_000ES-SRRM2-488-K27ac-594_13.tif
# Saved: img292_Lightning_052_000ES-SRRM2-488-K27ac-594_14.tif
# Saved: img293_Lightning_053_000ES-SRRM2-488-K27ac-594_15.tif
# Saved: img294_Lightning_054_000ES-SRRM2-488-K27ac-594_16.tif
# Saved: img295_Lightning_055_000ES-SRRM2-488-K27ac-594_17.tif
# Saved: img296_Lightning_056_000ES-SRRM2-488-K27ac-594_18.tif
# Saved: img297_Lightning_057_000ES-SRRM2-488-K27ac-594_19.tif
# Saved: img298_Lightning_058_000ES-SRRM2-488-K27ac-594_20.tif
# Saved: img299_Lightning_059_000ES-SRRM2-488-K27ac-594_21.tif
# Saved: img300_Lightning_060_000ES-SRRM2-488-K27ac-594_22.tif
# Done: 301/301 normalized
